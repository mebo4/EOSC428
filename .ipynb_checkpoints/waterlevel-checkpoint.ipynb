# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %% [markdown]
# ### Import Data

# %%
filename = "Water_Level_Field_Sheet.xlsx"
filename_p = "Vadose_Zone_Field_Sheets.xlsx"

# p1_16_02 = pd.read_excel(filename, skiprows = 7, sheet_name=0,
#                         names = ["date", "time", "well_name", "depth", "MSL","comments"])
# p2_16_02 = pd.read_excel(filename, skiprows = 7, sheet_name=1,
#                         names = ["date", "time", "well_name", "depth", "MSL","comments"])
# p3_16_02 = pd.read_excel(filename, skiprows = 7, sheet_name=2,
#                         names = ["date", "time", "well_name", "depth", "MSL","comments"])


# p1_18_01 = pd.read_excel(filename, skiprows = 7, sheet_name=3, nrows = 8,
#                         names = ["date", "time", "well_name", "depth", "MSL","comments"])
# p2_18_01 = pd.read_excel(filename, skiprows = 7, sheet_name=4, nrows = 8,
#                         names = ["date", "time", "well_name", "depth", "MSL","comments"])
# p3_18_01 = pd.read_excel(filename, skiprows = 7, sheet_name=5, nrows = 8,
#                         names = ["date", "time", "well_name", "depth", "MSL","comments"])

# # tensiometer data
# tens = pd.read_excel(filename_p, skiprows = 18, nrows = 5,
#                      names = ["date", "time", "p_shallow", "h_eq_shallow", "Ls", "Ls_plus_Zps",
#                              "p_deep", "h_eq_deep", "Ld", "Ld_plus_Zpd", "other"])

# tens

# %%
filename_loc = "Geodetic_Data_2020.xlsx"
loc = pd.read_excel(filename_loc,
                   names = ["pt", "description", "E", "N", "z", "other"])

plt.figure(figsize = (4, 6))
plt.scatter(loc["E"], loc["N"])
plt.scatter(loc[4:7]["E"], loc[4:7]["N"], c = 'r', label = "(top)16-02")
plt.scatter(loc[15:18]["E"], loc[15:18]["N"], c = 'r', label = "(bottom)18-01")
plt.xlim(4982, 4996)
plt.ylim(4750, 4940)
plt.xlabel("Easting (m)")
plt.ylabel("Northing (m)")
plt.title("Well Locations")
plt.legend()

plt.tight_layout()

loc
# Out:
#            pt                description         E         N      z  \
# 0   16-03-MW1  Reference Point Elevation  4988.462  4932.496  1.201
# 1   16-03-MW2  Reference Point Elevation  4988.417  4932.421  1.179
# 2   16-03-MW3  Reference Point Elevation  4988.474  4932.417  1.187
# 3    16-04-SP                  Standpipe  4988.503  4893.915  1.256
# 4   16-02-MW1  Reference Point Elevation  4988.555  4891.631  1.209
# 5   16-02-MW2  Reference Point Elevation  4988.532  4891.519  1.214
# 6   16-02-MW3  Reference Point Elevation  4988.416  4891.519  1.217
# 7       96-W3  Reference Point Elevation  4989.750  4852.180  1.002
# 8       96-W2     Ground Level Elevation  4990.041  4824.276  1.237
# 9          PW  Reference Point Elevation  4989.602  4819.760  0.981
# 10     96-114  Reference Point Elevation  4989.381  4815.422  1.168
# 11     96-105  Reference Point Elevation  4989.671  4803.730  1.136
# 12  16-01-MW1  Reference Point Elevation  4991.497  4754.095  1.804
# ...

# %%
def read_well_data(filename, sheet_indices):
    
    data = {}
    for idx in sheet_indices:
        sheet_key = f'sheet_{idx}'
        data[sheet_key] = pd.read_excel(
            filename,
            skiprows=7,
            sheet_name=idx,
            names=["date", "time", "well_name", "depth", "MSL", "comments"]
        )
    return data

# %%
sheet_indices = np.arange(0, 21, 1)
# sheet_indices

# %%
well_data = read_well_data(filename, sheet_indices)
# well_data

# %%
# Data from April 28
W96_105_28 = well_data['sheet_0']
W96_114_28 = well_data['sheet_1']
W16_01_28 = well_data['sheet_2']  # problem
W16_02_28 = well_data['sheet_3'] 
W16_03_28 = well_data['sheet_4']
W18_01_28 = well_data['sheet_5']
W18_02_28 = well_data['sheet_6']
W20_01_28 = well_data['sheet_7']
W20_02_28 = well_data['sheet_8']
W22_01_28 = well_data['sheet_9']
W24_01_28 = well_data['sheet_10']

# Data from April 29
W96_105_29 = well_data['sheet_11']
W96_114_29 = well_data['sheet_12']
W16_01_29 = well_data['sheet_13'] 
W16_02_29 = well_data['sheet_14'] 
W16_03_29 = well_data['sheet_15']
W18_01_29 = well_data['sheet_16']
W18_02_29 = well_data['sheet_17']
# W20_01_28 = well_data['sheet_7']  ???
# W20_02_28 = well_data['sheet_8']   ???
W22_01_29 = well_data['sheet_18']
W24_01_29 = well_data['sheet_19']
W25_01_29 = well_data['sheet_20']
# Out:
# 0.03100000000000014

# %%
fig, ax = plt.subplots(6, 2, figsize = (8, 16))
fig.suptitle("Water Level Over Time (April 28)", fontsize=16)

ax[0, 0].plot(W96_105_28['time'], loc['z'][11] - W96_105_28['depth'])
# ax[0, 0].axhline(y=loc['z'][11], color='red', label='Ground Level')
ax[0, 0].set_xlabel('Time(hrs)')        
ax[0, 0].set_ylabel('Hydraulic Head (m)')        
ax[0, 0].set_title('Well 96-105')  
# ax[0, 0].legend()
ax[0, 0].grid()

ax[0, 1].plot(W96_114_28['time'], loc['z'][10] - W96_114_28['depth'])
# ax[0, 1].axhline(y=loc['z'][10], color='red', label='Ground Level')
ax[0, 1].set_xlabel('Time(hrs)')        
ax[0, 1].set_ylabel('Hydraulic Head (m)')        
ax[0, 1].set_title('Well 96-114')
ax[0, 1].grid()

ax[1, 0].plot(W16_01_28['time'][0:6], loc['z'][12] - W16_01_28['depth'][0:6],
             label = 'MW1')
ax[1, 0].plot(W16_01_28['time'][7:13], loc['z'][13] - W16_01_28['depth'][7:13],
             label = 'MW2')
ax[1, 0].plot(W16_01_28['time'][14:20], loc['z'][14] - W16_01_28['depth'][14:20],
             label = 'MW3')
ax[1, 0].set_xlabel('Time(hrs)')        
ax[1, 0].set_ylabel('Hydraulic Head (m)')        
ax[1, 0].set_title('Well 16-01')  
ax[1, 0].legend()
ax[1, 0].grid()

ax[1, 1].plot(W16_02_28['time'][0:6], loc['z'][4] - W16_02_28['depth'][0:6],
             label = 'MW1')
ax[1, 1].plot(W16_02_28['time'][7:13], loc['z'][5] - W16_02_28['depth'][7:13],
             label = 'MW2')
ax[1, 1].plot(W16_02_28['time'][14:20], loc['z'][6] - W16_02_28['depth'][14:20],
             label = 'MW3')
ax[1, 1].set_xlabel('Time(hrs)')        
ax[1, 1].set_ylabel('Hydraulic Head (m)')        
ax[1, 1].set_title('Well 16-02')  
ax[1, 1].legend()
ax[1, 1].grid()

ax[2, 0].plot(W16_03_28['time'][0:6], loc['z'][0] - W16_03_28['depth'][0:6],
             label = 'MW1')
ax[2, 0].plot(W16_03_28['time'][7:13], loc['z'][1] - W16_03_28['depth'][7:13],
             label = 'MW2')
ax[2, 0].plot(W16_03_28['time'][14:20], loc['z'][2] - W16_03_28['depth'][14:20],
             label = 'MW3')
ax[2, 0].set_xlabel('Time(hrs)')        
ax[2, 0].set_ylabel('Hydraulic Head (m)')        
ax[2, 0].set_title('Well 16-03')  
ax[2, 0].legend()
ax[2, 0].grid()


ax[2, 1].plot(W18_01_28['time'][0:6], loc['z'][15] - W18_01_28['depth'][0:6],
             label = 'MW1')
ax[2, 1].plot(W18_01_28['time'][7:13], loc['z'][16] - W18_01_28['depth'][7:13],
             label = 'MW2')
ax[2, 1].plot(W18_01_28['time'][14:20], loc['z'][17] - W18_01_28['depth'][14:20],
             label = 'MW3')
ax[2, 1].set_xlabel('Time(hrs)')        
ax[2, 1].set_ylabel('Hydraulic Head (m)')        
ax[2, 1].set_title('Well 18-01')  
ax[2, 1].legend()
ax[2, 1].grid()

ax[3, 0].plot(W18_02_28['time'][0:6], loc['z'][18] - W18_02_28['depth'][0:6],
             label = 'MW1')
ax[3, 0].plot(W18_02_28['time'][7:13], loc['z'][19] - W18_02_28['depth'][7:13],
             label = 'MW2')
ax[3, 0].plot(W18_02_28['time'][14:20], loc['z'][20] - W18_02_28['depth'][14:20],
             label = 'MW3')
ax[3, 0].set_xlabel('Time(hrs)')        
ax[3, 0].set_ylabel('Hydraulic Head (m)')        
ax[3, 0].set_title('Well 18-02')  
ax[3, 0].legend()
ax[3, 0].grid()

ax[3, 1].plot(W20_01_28['time'], loc['z'][21] - W20_01_28['depth'])
ax[3, 1].set_xlabel('Time(hrs)')        
ax[3, 1].set_ylabel('Hydraulic Head (m)')        
ax[3, 1].set_title('Well 20-01')  
ax[3, 1].grid()


ax[4, 0].plot(W20_02_28['time'], loc['z'][22] - W20_02_28['depth'])
ax[4, 0].set_xlabel('Time(hrs)')        
ax[4, 0].set_ylabel('Hydraulic Head (m)')        
ax[4, 0].set_title('Well 20-01')  
ax[4, 0].grid()


ax[4, 1].plot(W22_01_28['time'][0:6], 1.866 - W22_01_28['depth'][0:6],
             label = 'MW1')
ax[4, 1].plot(W22_01_28['time'][7:13], 1.866 - W22_01_28['depth'][7:13],
             label = 'MW2')
ax[4, 1].plot(W22_01_28['time'][14:20], 1.866 - W22_01_28['depth'][14:20],
             label = 'MW3')
ax[4, 1].set_xlabel('Time(hrs)')        
ax[4, 1].set_ylabel('Hydraulic Head (m)')        
ax[4, 1].set_title('Well 22-01')  
ax[4, 1].legend()
ax[4, 1].grid()

ax[5, 0].plot(W24_01_28['time'], 1.6 - W24_01_28['depth'])
ax[5, 0].set_xlabel('Time(hrs)')        
ax[5, 0].set_ylabel('Hydraulic Head (m)')        
ax[5, 0].set_title('Well 24-01')  
ax[5, 0].grid()


ax[5, 1].axis('off')  


fig.savefig('April-28 data')
fig.tight_layout()
fig.show()
# Out:
# /var/folders/xx/z13_9gks5jj49hvr6ptgdslr0000gn/T/ipykernel_51759/1719122102.py:118: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots(5, 2, figsize = (8, 16))
fig.suptitle("Water Level Over Time (April 29)", fontsize=16)


ax[0, 0].plot(W96_105_29['time'], loc['z'][11] - W96_105_29['depth'])
ax[0, 0].set_xlabel('Time(hrs)')        
ax[0, 0].set_ylabel('Hydraulic Head (m)')        
ax[0, 0].set_title('Well 96-105')  
ax[0, 0].grid()

ax[0, 1].plot(W96_114_29['time'], loc['z'][10] - W96_114_29['depth'])
# ax[0, 1].axhline(y=loc['z'][10], color='red', label='Ground Level')
ax[0, 1].set_xlabel('Time(hrs)')        
ax[0, 1].set_ylabel('Hydraulic Head (m)')        
ax[0, 1].set_title('Well 96-114')
ax[0, 1].grid()

ax[1, 0].plot(W16_01_29['time'], loc['z'][12] - W16_01_29['depth'],
             label = 'MW1')
ax[1, 0].set_xlabel('Time(hrs)')        
ax[1, 0].set_ylabel('Hydraulic Head (m)')        
ax[1, 0].set_title('Well 16-01')  
ax[1, 0].legend()
ax[1, 0].grid()

ax[1, 1].plot(W16_02_29['time'][0:8], loc['z'][4] - W16_02_29['depth'][0:8],
             label = 'MW1')
ax[1, 1].plot(W16_02_29['time'][9:17], loc['z'][5] - W16_02_29['depth'][9:17],
             label = 'MW2')
ax[1, 1].plot(W16_02_29['time'][18:26], loc['z'][6] - W16_02_29['depth'][18:26],
             label = 'MW3')
ax[1, 1].set_xlabel('Time(hrs)')        
ax[1, 1].set_ylabel('Hydraulic Head (m)')        
ax[1, 1].set_title('Well 16-02')  
ax[1, 1].legend()
ax[1, 1].grid()

ax[2, 0].plot(W16_03_29['time'][0:8], loc['z'][0] - W16_03_29['depth'][0:8],
             label = 'MW1')
ax[2, 0].plot(W16_03_29['time'][9:17], loc['z'][1] - W16_03_29['depth'][9:17],
             label = 'MW2')
ax[2, 0].plot(W16_03_29['time'][18:26], loc['z'][2] - W16_03_29['depth'][18:26],
             label = 'MW3')
ax[2, 0].set_xlabel('Time(hrs)')        
ax[2, 0].set_ylabel('Hydraulic Head (m)')        
ax[2, 0].set_title('Well 16-03')  
ax[2, 0].legend()
ax[2, 0].grid()

ax[2, 1].plot(W18_01_29['time'][0:8], loc['z'][15] - W18_01_29['depth'][0:8],
             label = 'MW1')
ax[2, 1].plot(W18_01_29['time'][9:17], loc['z'][16] - W18_01_29['depth'][9:17],
             label = 'MW2')
ax[2, 1].plot(W18_01_29['time'][18:26], loc['z'][17] - W18_01_29['depth'][18:26],
             label = 'MW3')
ax[2, 1].set_xlabel('Time(hrs)')        
ax[2, 1].set_ylabel('Hydraulic Head (m)')        
ax[2, 1].set_title('Well 18-01')  
ax[2, 1].legend()
ax[2, 1].grid()

ax[3, 0].plot(W18_02_29['time'][0:6], loc['z'][18] - W18_02_29['depth'][0:6],
             label = 'MW1')
ax[3, 0].plot(W18_02_29['time'][7:13], loc['z'][19] - W18_02_29['depth'][7:13],
             label = 'MW2')
ax[3, 0].plot(W18_02_29['time'][14:20], loc['z'][20] - W18_02_29['depth'][14:20],
             label = 'MW3')
ax[3, 0].set_xlabel('Time(hrs)')        
ax[3, 0].set_ylabel('Hydraulic Head (m)')        
ax[3, 0].set_title('Well 18-02')  
ax[3, 0].legend()
ax[3, 0].grid()

ax[3, 1].plot(W22_01_29['time'][0:8], 1.866 - W22_01_29['depth'][0:8],
             label = 'MW1')
ax[3, 1].plot(W22_01_29['time'][9:17], 1.866 - W22_01_29['depth'][9:17],
             label = 'MW2')
ax[3, 1].plot(W22_01_29['time'][18:26], 1.866 - W22_01_29['depth'][18:26],
             label = 'MW3')
ax[3, 1].set_xlabel('Time(hrs)')        
ax[3, 1].set_ylabel('Hydraulic Head (m)')        
ax[3, 1].set_title('Well 22-01')  
ax[3, 1].legend()
ax[3, 1].grid()

ax[4, 0].plot(W24_01_29['time'], 1.6 - W24_01_29['depth'])
ax[4, 0].set_xlabel('Time(hrs)')        
ax[4, 0].set_ylabel('Hydraulic Head (m)')        
ax[4, 0].set_title('Well 24-01')  
ax[4, 0].grid()

ax[4, 1].plot(W25_01_29['time'], 1.19 - W25_01_29['depth'])
ax[4, 1].set_xlabel('Time(hrs)')        
ax[4, 1].set_ylabel('Hydraulic Head (m)')        
ax[4, 1].set_title('Well 25-01')  
ax[4, 1].grid()


fig.savefig('April-29 data')
fig.tight_layout()
fig.show()
# Out:
# /var/folders/xx/z13_9gks5jj49hvr6ptgdslr0000gn/T/ipykernel_51759/1821526975.py:101: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
E = np.array(loc["E"])
N = np.array(loc["N"])
Z = np.array(loc["z"])

grid_E, grid_N = np.meshgrid(
    np.linspace(E.min(), E.max(), 100),
    np.linspace(N.min(), N.max(), 100)
)

grid_Z = griddata((E, N), Z, (grid_E, grid_N), method='linear')

plt.figure(figsize=(6, 6))
contour = plt.contourf(grid_E, grid_N, grid_Z, levels=20, cmap='jet')
plt.colorbar(contour, label='Z (m)')
plt.xlabel('E (m)')
plt.ylabel('N (m)')
plt.xlim(4982, 4996)
plt.ylim(4750, 4940)
plt.title('Contour Plot of Elevation')
plt.scatter(loc["E"], loc["N"], c = 'k')
# plt.scatter(loc[4:7]["E"], loc[4:7]["N"], c = 'r', label = "(top)16-02")
# plt.scatter(loc[15:18]["E"], loc[15:18]["N"], c = 'r', label = "(bottom)18-01")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sorted_indices = np.argsort(loc['N'])[::-1]  

north_to_south = loc['N'][sorted_indices]
sorted_z = loc['z'][sorted_indices]

plt.plot(north_to_south, sorted_z, label = "Elevation")
plt.ylim(-7, 4)
plt.scatter(loc['N'][0], loc['z'][0] - W16_03_28['depth'][0], 
           label = '16-03', c = 'r')
plt.scatter(loc['N'][4], loc['z'][4] - W16_02_28['depth'][0],
            label = '16-02', c = 'k')
plt.scatter(loc['N'][18], loc['z'][18] - W18_02_28['depth'][0],
            label = '18-02', c = 'b')
plt.scatter(loc['N'][10], loc['z'][10] - W96_114_28['depth'][0],
            label = '96-114', c = 'g')
plt.scatter(loc['N'][11], loc['z'][11] - W96_105_28['depth'][0],
            label = '96-105', c = 'y')
plt.scatter(loc['N'][15], loc['z'][15] - W18_01_28['depth'][0],
            label = '18-01', c = 'c')
plt.scatter(loc['N'][21], loc['z'][21] - W20_01_28['depth'][0],
            label = '20-01')
plt.scatter(loc['N'][22], loc['z'][22] - W20_02_28['depth'][0],
            label = '20-02')
plt.scatter(loc['N'][12], loc['z'][12] - W16_01_28['depth'][0],
            label = '16-01')

    
plt.legend()

# %%
x_values = [
    loc['N'][0],
    loc['N'][4],
    loc['N'][18],
    loc['N'][10],
    loc['N'][11],
    loc['N'][15],
    loc['N'][21],
    loc['N'][22],
    loc['N'][12]
]

# %%
h_time_0 = np.array([
    loc['z'][0]  - W16_03_28['depth'][0],
    loc['z'][4]  - W16_02_28['depth'][0],
    loc['z'][18] - W18_02_28['depth'][0],
    loc['z'][10] - W96_114_28['depth'][0],
    loc['z'][11] - W96_105_28['depth'][0],
    loc['z'][15] - W18_01_28['depth'][0],
    loc['z'][21] - W20_01_28['depth'][0],
    loc['z'][22] - W20_02_28['depth'][0],
    loc['z'][12] - W16_01_28['depth'][0]
])

h_time_3 = np.array([
    loc['z'][0]  - W16_03_28['depth'][3],
    loc['z'][4]  - W16_02_28['depth'][3],
    loc['z'][18] - W18_02_28['depth'][3],
    loc['z'][10] - W96_114_28['depth'][3],
    loc['z'][11] - W96_105_28['depth'][3],
    loc['z'][15] - W18_01_28['depth'][3],
    loc['z'][21] - W20_01_28['depth'][3],
    loc['z'][22] - W20_02_28['depth'][3],
    loc['z'][12] - W16_01_28['depth'][3]
])

h_time_5 = np.array([
    loc['z'][0]  - W16_03_28['depth'][5],
    loc['z'][4]  - W16_02_28['depth'][5],
    loc['z'][18] - W18_02_28['depth'][5],
    loc['z'][10] - W96_114_28['depth'][5],
    loc['z'][11] - W96_105_28['depth'][5],
    loc['z'][15] - W18_01_28['depth'][5],
    loc['z'][21] - W20_01_28['depth'][5],
    loc['z'][22] - W20_02_28['depth'][5],
    loc['z'][12] - W16_01_28['depth'][5]
])

# %%
plt.plot(north_to_south, sorted_z, label = "Elevation")
plt.ylim(-7, 4)
plt.plot(x_values, h_time_0, label = "Hydraulic Head at Time 0")
plt.plot(x_values, h_time_3, label = "Hydraulic Head at Time 3")
plt.plot(x_values, h_time_5, label = "Hydraulic Head at Time 5")
plt.legend()

# %% [markdown]
# ### Calculate Hydraulic Head From Tensiometer
# $$h = \frac{\psi}{\rho_w g} + z$$

# %%
tens["time"] = [0, 3.5, 17.2]
tens

# %%
elevation = 1.2 #m
z_deep = elevation -0.2 #m
z_shallow = elevation -0.16 #m
rho_water = 1000  # kg/m^3
g = 9.81 # m/s^2

# %%
h_shallow = tens["p_shallow"] / (rho_water * g) + z_shallow
h_deep =  tens["p_deep"] / (rho_water * g) + z_deep

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(tens["time"], h_shallow)
ax[0].set_title("Hydraulic Head (Shallow Tensiometer)")
ax[0].set_xlabel("Time (hrs)")
ax[0].set_ylabel("Hydraulic Head")

ax[1].plot(tens["time"], h_deep)
ax[1].set_title("Hydraulic Head (Deep Tensiometer)")
ax[1].set_xlabel("Time (hrs)")
ax[1].set_ylabel("Hydraulic Head")

plt.tight_layout()

# %% [markdown]
# ### Plot Well Locations

# %%
E = np.array(loc["E"])
N = np.array(loc["N"])
Z = np.array(loc["z"])

grid_E, grid_N = np.meshgrid(
    np.linspace(E.min(), E.max(), 100),
    np.linspace(N.min(), N.max(), 100)
)

grid_Z = griddata((E, N), Z, (grid_E, grid_N), method='linear')

plt.figure(figsize=(6, 6))
contour = plt.contourf(grid_E, grid_N, grid_Z, levels=20, cmap='jet')
plt.colorbar(contour, label='Z (m)')
plt.xlabel('E (m)')
plt.ylabel('N (m)')
plt.xlim(4982, 4996)
plt.ylim(4750, 4940)
plt.title('Contour Plot of Elevation')
plt.scatter(loc["E"], loc["N"], c = 'k')
plt.scatter(loc[4:7]["E"], loc[4:7]["N"], c = 'r', label = "(top)16-02")
plt.scatter(loc[15:18]["E"], loc[15:18]["N"], c = 'r', label = "(bottom)18-01")
plt.legend()
# plt.scatter(E, N, c=Z, edgecolor='k', cmap='jet')
